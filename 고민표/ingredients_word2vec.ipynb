# %%
import gensim
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer 
import numpy as np
import pandas as pd
import pickle

# %%
with open ('/content/drive/MyDrive/Recipe/ingredidents_pre.p', 'rb') as f:
  ingredients = pickle.load(f)

# %%
#size = 임베딩벡터의 차원
#min_count: 언급된 단어는 반영하지 않음
#0은 CBOW(여러개로 하나 추정), 1은 skip-gram(하나로 여러개 추정)
#worker는 학습을 위한 프로세스 수(1이 기본인듯)
model= Word2Vec(sentences=ingredients, size=100, window=5, min_count=1, workers=4, sg=0, iter = 250)

# %%
a = model.wv.most_similar("돼지고기")
print(a)

# %%
#유사도 뽑기
no = []
sim = 0.5
for i in model.wv.vocab.keys():
  if model.wv.similarity('돼지', i) >= sim:
    no.append(i)
print(no)

# %%
model.wv.similarity('고구마', '단호박')

# %%
model.save('/content/drive/MyDrive/Recipe/wvrecipe')
